# %%
from src.utils import *

# %%
mutator = rvMutator()
(sim_input, data, assert_intr) =mutator.read_siminput('/home/em-student/Documents/fuzz_out/corpus/id_0.si')

# %%
sim_input.save('/home/em-student/Documents/fuzz_out/corpus/id_3.si', data)

# %%
(s, d, assert_intr) =mutator.read_siminput('/home/em-student/Documents/fuzz_out/corpus/id_3.si')
s.save('/home/em-student/Documents/fuzz_out/corpus/id_4.si', d)

# %%
data
# Out:
# ([9834499053455428892,
#   16155195309910649428,
#   17580839021073989711,
#   3862402066288063356,
#   6874525155059204194,
#   11870748148628109447,
#   7134351959747558628,
#   929325077589981926,
#   16969394488460599918,
#   17661920064757899606,
#   10572223640626814816,
#   7266511519952908195,
#   13720254205092649447,
#   9283297148927557298,
#   6048476214937618738,
#   5390082866765169178,
#   14132131983679262370,
#   11645253206039970989,
#   17777656383786299740,
#   16816808056081559808,
#   7686652681116438951,
#   7919438847031794750,
#   8665818045413096336,
#   13286686177592414730,
#   14859582387591370877,
#   2694921592571807498,
#   17396735195727207053,
#   9136176554103501130,
#   1099219605033373435,
#   7310222482916390011,
#   17765048104561822669,
#   11510626106710208412,
#   5351154217493944369,
#   10699007148126909632,
#   16583599654535089654,
#   12475933711324426968,
#   18155585845286300569,
#   16873356286391994671,
#   1470726544205687938,
# ...
